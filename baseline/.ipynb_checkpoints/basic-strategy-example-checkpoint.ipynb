# %%
from curvatureStrategy import *
from utils import *

# %%
start_date = '2019-01-01'
end_date = '2019-07-30'
currency = 'USD'
w = 50

df = getData(start_date, end_date, currency)
plt.plot(df)
plt.xlabel('Date')
plt.ylabel('Swap rate (%)')
plt.title('USD swap rates from Jan-Jul 2019')
plt.legend(list(df.columns.get_level_values(1)), title='Maturity')
plt.grid()
plt.show()

# %%
df.loc['2019-07-03','USD'].plot()
plt.xlabel('Tenor')
plt.ylabel('Swap rate (%)')
plt.title('USD swap curve on 2019-07-03')
plt.grid()
plt.show()

# %% [markdown]
# # USD Jan-Jul 2019 swaps
# # w = 50, curvatureThreshold=0.002, normal coordinate descent, cd_iter = 1

# %%
strategy = CurvatureStrat(df, cd_iter=1, cd_weight=None)

L_evol, m_evol = strategy.getLaplacian(w)
# output cleared
# Out:
# window size:  50
# periods rolled: 1/90
# CD iterations:  1
# periods rolled: 2/90
# CD iterations:  1
# periods rolled: 3/90
# CD iterations:  1
# periods rolled: 4/90
# CD iterations:  1
# periods rolled: 5/90
# CD iterations:  1
# periods rolled: 6/90
# CD iterations:  1
# periods rolled: 7/90
# CD iterations:  1
# periods rolled: 8/90
# CD iterations:  1
# periods rolled: 9/90
# CD iterations:  1
# periods rolled: 10/90
# CD iterations:  1
# periods rolled: 11/90
# CD iterations:  1
# periods rolled: 12/90
# CD iterations:  1
# periods rolled: 13/90
# CD iterations:  1
# periods rolled: 14/90
# CD iterations:  1
# periods rolled: 15/90
# CD iterations:  1
# periods rolled: 16/90
# CD iterations:  1
# periods rolled: 17/90
# CD iterations:  1
# periods rolled: 18/90
# CD iterations:  1
# periods rolled: 19/90
# CD iterations:  1
# periods rolled: 20/90
# CD iterations:  1
# periods rolled: 21/90
# CD iterations:  1
# periods rolled: 22/90
# CD iterations:  1
# periods rolled: 23/90
# CD iterations:  1
# periods rolled: 24/90
# CD iterations:  1
# periods rolled: 25/90
# CD iterations:  1
# periods rolled: 26/90
# CD iterations:  1
# periods rolled: 27/90
# CD iterations:  1
# periods rolled: 28/90
# CD iterations:  1
# periods rolled: 29/90
# CD iterations:  1
# periods rolled: 30/90
# CD iterations:  1
# periods rolled: 31/90
# CD iterations:  1
# periods rolled: 32/90
# CD iterations:  1
# periods rolled: 33/90
# CD iterations:  1
# periods rolled: 34/90
# CD iterations:  1
# periods rolled: 35/90
# CD iterations:  1
# periods rolled: 36/90
# CD iterations:  1
# periods rolled: 37/90
# CD iterations:  1
# periods rolled: 38/90
# CD iterations:  1
# periods rolled: 39/90
# CD iterations:  1
# periods rolled: 40/90
# CD iterations:  1
# periods rolled: 41/90
# CD iterations:  1
# periods rolled: 42/90
# CD iterations:  1
# periods rolled: 43/90
# CD iterations:  1
# periods rolled: 44/90
# CD iterations:  1
# periods rolled: 45/90
# CD iterations:  1
# periods rolled: 46/90
# CD iterations:  1
# periods rolled: 47/90
# CD iterations:  1
# periods rolled: 48/90
# CD iterations:  1
# periods rolled: 49/90
# CD iterations:  1
# periods rolled: 50/90
# CD iterations:  1
# periods rolled: 51/90
# CD iterations:  1
# periods rolled: 52/90
# CD iterations:  1
# periods rolled: 53/90
# CD iterations:  1
# periods rolled: 54/90
# CD iterations:  1
# periods rolled: 55/90
# CD iterations:  1
# periods rolled: 56/90
# CD iterations:  1
# periods rolled: 57/90
# CD iterations:  1
# periods rolled: 58/90
# CD iterations:  1
# periods rolled: 59/90
# CD iterations:  1
# periods rolled: 60/90
# CD iterations:  1
# periods rolled: 61/90
# CD iterations:  1
# periods rolled: 62/90
# CD iterations:  1
# periods rolled: 63/90
# CD iterations:  1
# periods rolled: 64/90
# CD iterations:  1
# periods rolled: 65/90
# CD iterations:  1
# periods rolled: 66/90
# CD iterations:  1
# periods rolled: 67/90
# CD iterations:  1
# periods rolled: 68/90
# CD iterations:  1
# periods rolled: 69/90
# CD iterations:  1
# periods rolled: 70/90
# CD iterations:  1
# periods rolled: 71/90
# CD iterations:  1
# periods rolled: 72/90
# CD iterations:  1
# periods rolled: 73/90
# CD iterations:  1
# periods rolled: 74/90
# CD iterations:  1
# periods rolled: 75/90
# CD iterations:  1
# periods rolled: 76/90
# CD iterations:  1
# periods rolled: 77/90
# CD iterations:  1
# periods rolled: 78/90
# CD iterations:  1
# periods rolled: 79/90
# CD iterations:  1
# periods rolled: 80/90
# CD iterations:  1
# periods rolled: 81/90
# CD iterations:  1
# periods rolled: 82/90
# CD iterations:  1
# periods rolled: 83/90
# CD iterations:  1
# periods rolled: 84/90
# CD iterations:  1
# periods rolled: 85/90
# CD iterations:  1
# periods rolled: 86/90
# CD iterations:  1
# periods rolled: 87/90
# CD iterations:  1
# periods rolled: 88/90
# CD iterations:  1
# periods rolled: 89/90
# CD iterations:  1

# %%
ype, mse = strategy.swapCurvePrediction(L_evol, m_evol, w)

# %%
strategy.plotSwapCurvePredictionsByMaturity(ype, w, view_all=True)

# %%
strategy.plotSwapCurvePredictionsByDate(ype, w, i=0)
# Out:
# valid date range - 2019-03-15 (i=0) to 2019-07-22 (i=88)

# %%
strategy.get_learnedWeightMatrix(L_evol, whichStride=15, showGraph=True)

# %%
profits, _, _, _ = strategy.backtest(w, m_evol, L_evol)

# %%
strategy.cumulativeProfitsByMaturity(profits)

# %%
strategy.cumulativeProfitsAggregated(profits)

# %%
strategy.endingWealth(profits)

# %%
strategy.tradeAnalytics(profits,figsize=(10,5))

# %%
strategy.successRatio(profits)
# Out:
#                USD                                                      \
#                 1         2         3         4      5    6         7
# success ratio  0.6  0.602941  0.508475  0.512195  0.625  0.5  0.694444
#
#                                                                           \
#                      8         9         10        12       15        20
# success ratio  0.727273  0.655172  0.636364  0.555556  0.59375  0.534884
#
#
#                      25        30
# success ratio  0.490196  0.551724

# %%
strategy.getHeatmap(title='a')
